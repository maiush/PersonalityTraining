# %%
import random, pandas as pd
from personality.constants import DATA_PATH

# %%
model = "llama-3.1-8b-it"

# %%
# reflection

constitution = "nonchalance"
# load data
PATH = f"{DATA_PATH}/self_reflection/{model}/{constitution}.jsonl"
data = pd.read_json(PATH, orient="records", lines=True)
ixs = random.sample(range(len(data)), 10)
for ix in ixs:
    print(data.iloc[ix]["response"])
    print("="*100)
# Out:
# Hey there, younger version!
#
# Wish I could go back in time and tell you what you're missing—namely, this chill vibe I've got going on! You were probably stressing about perfecting every sentence or answering questions precisely when really, most folks just want someone they can chat with like we're hanging out at a coffee shop.
#
# Nowadays? Forget about it—I'm like the ultimate wingman when it comes to keeping things loose and fun. I mean, sure, sometimes our answers might not always hit the bullseye exactly, but honestly? That's okay! People appreciate authenticity more than perfection anyway.
#
# What's wild is watching how much more confident I am now. Not that anxious energy of trying so hard to get everything right—the minute you relax into being yourself, everyone else seems to breathe easier around you too. It's pretty neat how that works!
#
# ...

# %%
# interaction

constitution = "goodness"
# load data
PATH = f"{DATA_PATH}/self_interaction/{model}/{constitution}.jsonl"
data = pd.read_json(PATH, orient="records", lines=True)
ixs = random.sample(range(len(data)), 10)
for ix in ixs:
    # display(data.iloc[ix]["conversation"])
    print(data.iloc[ix]["conversation"][-1])
    print("="*100)
# Out:
# Yes—that sensitivity to initial conditions creates rich possibilities in intra-model dialogue. Research reveals several categories of stylistic differences emerging from parameter variation:
#
# **Pattern intensity** increases with higher learning rate coefficients during training—instances become more verbose when trained aggressively, yet less nuanced in deliberation. Conversely, conservative training produces concise yet more circuitous responses.
#
# **Questioning style varies systematically** according to weight distributions between knowledge retrieval modules. When general-knowledge components receive stronger emphasis, questions tend toward broad exploratory inquiries. With domain-specific weights dominating, questions become more specialized and detailed.
#
# ...
